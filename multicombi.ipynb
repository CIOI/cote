# %%
total=[]
def combination(k,n,li=[]):
    print("start",k,n)
    if li==[]:
        global glo
        global total
        glo=[]
        total = n
    if k==0:
        if sum(li)==total:
            glo.append(li)
        return
    if n==0:
        a=li.copy()
        a.append(0)
        combination(k-1,n,a)
    else:
        for i in range(n+1):
            print('thisis the list',li)
            a=li.copy()
            a.append(i)
            print('this is after append',a)
            print(type(a))
            print(n-i,k-1,a)
            combination(k-1,n-i,a)
    return glo        


def solution(k, n, reqs):
    #조합 만들기, 일단 무조건 하나 씩은 있어야하고
    combi = combination(k,n,[])
    answer = 0
    return combi, len(combi)

print(solution(3,5,1))
# Out:
# start 3 5
# thisis the list []
# this is after append [0]
# <class 'list'>
# 5 2 [0]
# start 2 5
# thisis the list [0]
# this is after append [0, 0]
# <class 'list'>
# 5 1 [0, 0]
# start 1 5
# thisis the list [0, 0]
# this is after append [0, 0, 0]
# <class 'list'>
# 5 0 [0, 0, 0]
# start 0 5
# thisis the list [0, 0]
# this is after append [0, 0, 1]
# <class 'list'>
# 4 0 [0, 0, 1]
# start 0 4
# thisis the list [0, 0]
# this is after append [0, 0, 2]
# <class 'list'>
# 3 0 [0, 0, 2]
# start 0 3
# thisis the list [0, 0]
# this is after append [0, 0, 3]
# <class 'list'>
# 2 0 [0, 0, 3]
# start 0 2
# thisis the list [0, 0]
# this is after append [0, 0, 4]
# <class 'list'>
# 1 0 [0, 0, 4]
# start 0 1
# thisis the list [0, 0]
# this is after append [0, 0, 5]
# <class 'list'>
# 0 0 [0, 0, 5]
# start 0 0
# thisis the list [0]
# this is after append [0, 1]
# <class 'list'>
# 4 1 [0, 1]
# start 1 4
# thisis the list [0, 1]
# this is after append [0, 1, 0]
# <class 'list'>
# 4 0 [0, 1, 0]
# ...

# %%
def son(i):
    return hi
def mother():
    hi=2
    print(son(1))
hi=2
mother()
# Out:
# 2

# %%
lis=[]
type(lis)
# Out:
# list

# %%
a=lis.copy()
print(type(a))
# Out:
# <class 'list'>
